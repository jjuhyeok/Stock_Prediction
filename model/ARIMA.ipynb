# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import random
import os

from tqdm import tqdm
from statsmodels.tsa.arima.model import ARIMA

import warnings
warnings.filterwarnings("ignore")

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Data Load

# %%
train = pd.read_csv('./train.csv')

# %% [markdown]
# # Arima

# %%
# 추론 결과를 저장하기 위한 dataframe 생성
results_df = pd.DataFrame(columns=['종목코드', 'final_return'])
# train 데이터에 존재하는 독립적인 종목코드 추출
unique_codes = train['종목코드'].unique()

# 각 종목코드에 대해서 모델 학습 및 추론 반복
for code in tqdm(unique_codes):
    
    # 학습 데이터 생성
    train_close = train[train['종목코드'] == code][['일자', '종가']]
    train_close['일자'] = pd.to_datetime(train_close['일자'], format='%Y%m%d')
    train_close.set_index('일자', inplace=True)
    tc = train_close['종가']
    
    # 모델 선언, 학습 및 추론
    model = ARIMA(tc, order=(2, 1, 2))
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=15) # 향후 15개의 거래일에 대해서 예측
    
    # 최종 수익률 계산
    final_return = (predictions.iloc[-1] - predictions.iloc[0]) / predictions.iloc[0]
    
    # 결과 저장
    results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
    
results_df['순위'] = results_df['final_return'].rank(method='first').astype('int') # 각 순위를 중복없이 생성
results_df
# Out:
# 100%|██████████| 2000/2000 [08:30<00:00,  3.92it/s]

# %% [markdown]
# # Auto_Arima

# %%
import pandas as pd
import pmdarima as pm
from tqdm import tqdm

# 결과 저장을 위한 DataFrame 생성
results_df = pd.DataFrame(columns=['종목코드', 'final_return'])

# train 데이터에 존재하는 독립적인 종목코드 추출
unique_codes = train['종목코드'].unique()

# 각 종목코드에 대해서 모델 학습 및 추론 반복
for code in tqdm(unique_codes):
    
    # 학습 데이터 생성
    train_close = train[train['종목코드'] == code]['종가']
    train_close.index = pd.to_datetime(train[train['종목코드'] == code]['일자'], format='%Y%m%d')

    # 모델 선언 및 학습
    model = pm.auto_arima(train_close, error_action='ignore', trace=False,
                          suppress_warnings=True, maxiter=10,
                          seasonal=True, m=12)

    # 예측
    predictions = model.predict(n_periods=15)

    # 최종 수익률 계산
    final_return = (predictions.iloc[-1] - predictions.iloc[0]) / predictions.iloc[0]
    
    # 결과 저장
    results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)

results_df['순위'] = results_df['final_return'].rank(method='first').astype('int') # 각 순위를 중복없이 생성
# Out:
# 100%|██████████| 2000/2000 [1:58:55<00:00,  3.57s/it]
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[27], line 32
#      29     # 결과 저장
#      30     results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# ---> 32 results_df['순위'] = results_df['final_return'].rank(method='first').astype('int') # 각 순위를 중복없이 생성
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\generic.py:6240, in astype(self, dtype, copy, errors)
#    6161 def astype(
#    6162     self: NDFrameT, dtype, copy: bool_t | None = None, errors: IgnoreRaise = "raise"
#    6163 ) -> NDFrameT:
#    6164     """
#    6165     Cast a pandas object to a specified dtype ``dtype``.
#    6166
#    6167     Parameters
#    6168     ----------
#    6169     dtype : str, data type, Series or Mapping of column name -> data type
#    6170         Use a str, numpy.dtype, pandas.ExtensionDtype or Python type to
#    6171         cast entire pandas object to the same type. Alternatively, use a
#    6172         mapping, e.g. {col: dtype, ...}, where col is a column label and dtype is
#    6173         a numpy.dtype or Python type to cast one or more of the DataFrame's
#    6174         columns to column-specific types.
#    6175     copy : bool, default True
#    6176         Return a copy when ``copy=True`` (be very careful setting
#    6177         ``copy=False`` as changes to values then may propagate to other
#    6178         pandas objects).
#    6179     errors : {'raise', 'ignore'}, default 'raise'
#    6180         Control raising of exceptions on invalid data for provided dtype.
#    6181
#    6182         - ``raise`` : allow exceptions to be raised
#    6183         - ``ignore`` : suppress exceptions. On error return original object.
#    6184
#    6185     Returns
#    6186     -------
#    6187     same type as caller
#    6188
#    6189     See Also
#    6190     --------
#    6191     to_datetime : Convert argument to datetime.
#    6192     to_timedelta : Convert argument to timedelta.
#    6193     to_numeric : Convert argument to a numeric type.
#    6194     numpy.ndarray.astype : Cast a numpy array to a specified type.
#    6195
#    6196     Notes
#    6197     -----
#    6198     .. versionchanged:: 2.0.0
#    6199
#    6200         Using ``astype`` to convert from timezone-naive dtype to
#    6201         timezone-aware dtype will raise an exception.
#    6202         Use :meth:`Series.dt.tz_localize` instead.
#    6203
#    6204     Examples
#    6205     --------
#    6206     Create a DataFrame:
#    6207
#    6208     >>> d = {'col1': [1, 2], 'col2': [3, 4]}
#    6209     >>> df = pd.DataFrame(data=d)
#    6210     >>> df.dtypes
#    6211     col1    int64
#    6212     col2    int64
#    6213     dtype: object
#    6214
#    6215     Cast all columns to int32:
#    6216
#    6217     >>> df.astype('int32').dtypes
#    6218     col1    int32
#    6219     col2    int32
#    6220     dtype: object
#    6221
#    6222     Cast col1 to int32 using a dictionary:
#    6223
#    6224     >>> df.astype({'col1': 'int32'}).dtypes
#    6225     col1    int32
#    6226     col2    int64
#    6227     dtype: object
#    6228
#    6229     Create a series:
#    6230
#    6231     >>> ser = pd.Series([1, 2], dtype='int32')
#    6232     >>> ser
#    6233     0    1
#    6234     1    2
#    6235     dtype: int32
#    6236     >>> ser.astype('int64')
#    6237     0    1
#    6238     1    2
#    6239     dtype: int64
# -> 6240
#    6241     Convert to categorical type:
#    6242
#    6243     >>> ser.astype('category')
#    6244     0    1
#    6245     1    2
#    6246     dtype: category
#    6247     Categories (2, int32): [1, 2]
#    6248
#    6249     Convert to ordered categorical type with custom ordering:
#    6250
#    6251     >>> from pandas.api.types import CategoricalDtype
#    6252     >>> cat_dtype = CategoricalDtype(
#    6253     ...     categories=[2, 1], ordered=True)
#    6254     >>> ser.astype(cat_dtype)
#    6255     0    1
#    6256     1    2
#    6257     dtype: category
#    6258     Categories (2, int64): [2 < 1]
#    6259
#    6260     Create a series of dates:
#    6261
#    6262     >>> ser_date = pd.Series(pd.date_range('20200101', periods=3))
#    6263     >>> ser_date
#    6264     0   2020-01-01
#    6265     1   2020-01-02
#    6266     2   2020-01-03
#    6267     dtype: datetime64[ns]
#    6268     """
#    6269     if copy and using_copy_on_write():
#    6270         copy = False
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\internals\managers.py:448, in astype(self, dtype, copy, errors)
#     446     else:
#     447         copy = True
# --> 448 elif using_copy_on_write():
#     449     copy = False
#     451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#    (...)
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\internals\managers.py:352, in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\internals\blocks.py:526, in astype(self, dtype, copy, errors)
#     520 if newb.shape != self.shape:
#     521     raise TypeError(
#     522         f"cannot set astype for copy = [{copy}] for dtype "
#     523         f"({self.dtype.name} [{self.shape}]) to different shape "
#     524         f"({newb.dtype.name} [{newb.shape}])"
#     525     )
# --> 526 return newb
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     295 if new_numpy_dtype is None and isinstance(new_dtype, np.dtype):
#     296     new_numpy_dtype = new_dtype
#     298 if numpy_dtype is not None and new_numpy_dtype is not None:
# --> 299     # if both have NumPy dtype or one of them is a numpy dtype
#     300     # they are only a view when the numpy dtypes are equal, e.g.
#     301     # int64 -> Int64 or int64[pyarrow]
#     302     # int64 -> Int32 copies
#     303     return numpy_dtype == new_numpy_dtype
#     305 # Assume this is a view since we don't know for sure if a copy was made
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     raise ValueError(invalid_arg)
#     229 if inspect.isclass(dtype) and issubclass(dtype, ExtensionDtype):
# --> 230     msg = (
#     231         f"Expected an instance of {dtype.__name__}, "
#     232         "but got the class instead. Try instantiating 'dtype'."
#     233     )
#     234     raise TypeError(msg)
#     236 dtype = pandas_dtype(dtype)
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\dtypes\astype.py:140, in astype_nansafe(arr, dtype, copy, skipna)
#     136 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     137     # Explicit copy, or required since NumPy can't view from / to object.
#     138     return arr.astype(dtype, copy=True)
# --> 140 return arr.astype(dtype, copy=copy)
#
# File c:\Users\ineeji\anaconda3\envs\v1\lib\site-packages\pandas\core\dtypes\astype.py:182, in _astype_float_to_int_nansafe(values, dtype, copy)
#     179         return values.copy()
#     180     return values
# --> 182 if not isinstance(values, np.ndarray):
#     183     # i.e. ExtensionArray
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
results_df.isnull().sum().sum()
# Out:
# 9

# %% [markdown]
# # Prophet

# %%
#from fbprophet import Prophet
from prophet import Prophet

# 추론 결과를 저장하기 위한 dataframe 생성
results_df = pd.DataFrame(columns=['종목코드', 'final_return'])

# train 데이터에 존재하는 독립적인 종목코드 추출
unique_codes = train['종목코드'].unique()

# 각 종목코드에 대해서 모델 학습 및 추론 반복
for code in tqdm(unique_codes):
    
    # 학습 데이터 생성
    train_close = train[train['종목코드'] == code][['일자', '종가']]
    train_close = train_close.rename(columns={'일자': 'ds', '종가': 'y'})  # Prophet expects the date column to be 'ds' and the value column to be 'y'
    train_close['ds'] = pd.to_datetime(train_close['ds'], format='%Y%m%d')

    # 모델 선언, 학습 및 추론
    model = Prophet(daily_seasonality=True)  # Prophet model declaration
    model.fit(train_close)  # fit the model with your dataframe
    future = model.make_future_dataframe(periods=15)  # we need to specify the number of days we want to predict into the future
    predictions = model.predict(future)
    
    # 최종 수익률 계산
    final_return = (predictions['yhat'].iloc[-1] - predictions['yhat'].iloc[-15]) / predictions['yhat'].iloc[-15]
    
    # 결과 저장
    results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)

results_df['순위'] = results_df['final_return'].rank(method='first').astype('int') # 각 순위를 중복없이 생성
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]15:21:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:49 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 1/2000 [00:00<26:11,  1.27it/s]15:21:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:49 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 2/2000 [00:01<20:05,  1.66it/s]15:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:50 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 3/2000 [00:01<16:57,  1.96it/s]15:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:50 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 4/2000 [00:02<15:21,  2.17it/s]15:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 5/2000 [00:02<14:18,  2.32it/s]15:21:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 6/2000 [00:02<13:14,  2.51it/s]15:21:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 7/2000 [00:03<13:27,  2.47it/s]15:21:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:52 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 8/2000 [00:03<13:25,  2.47it/s]15:21:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:52 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 9/2000 [00:03<13:29,  2.46it/s]15:21:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:53 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 10/2000 [00:04<14:38,  2.26it/s]15:21:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:53 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 11/2000 [00:04<13:54,  2.38it/s]15:21:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:53 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 12/2000 [00:05<13:45,  2.41it/s]15:21:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:54 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 13/2000 [00:05<13:19,  2.49it/s]15:21:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:54 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 14/2000 [00:06<13:31,  2.45it/s]15:21:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:55 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 15/2000 [00:06<13:37,  2.43it/s]15:21:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:55 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 16/2000 [00:06<13:32,  2.44it/s]15:21:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:56 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 17/2000 [00:07<14:06,  2.34it/s]15:21:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:56 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 18/2000 [00:07<14:25,  2.29it/s]15:21:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:57 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 19/2000 [00:08<15:19,  2.16it/s]15:21:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:57 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 20/2000 [00:08<14:43,  2.24it/s]15:21:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:57 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 21/2000 [00:09<14:27,  2.28it/s]15:21:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:58 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 22/2000 [00:09<14:32,  2.27it/s]15:21:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:58 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 23/2000 [00:10<14:27,  2.28it/s]15:21:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:59 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 24/2000 [00:10<13:56,  2.36it/s]15:21:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:59 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 25/2000 [00:10<13:25,  2.45it/s]15:21:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:21:59 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 26/2000 [00:11<13:03,  2.52it/s]15:22:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:00 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 27/2000 [00:11<13:43,  2.40it/s]15:22:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:00 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 28/2000 [00:12<13:41,  2.40it/s]15:22:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:01 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 29/2000 [00:12<14:11,  2.32it/s]15:22:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:01 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 30/2000 [00:12<14:14,  2.30it/s]15:22:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:02 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 31/2000 [00:13<13:57,  2.35it/s]15:22:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:02 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 32/2000 [00:13<13:21,  2.46it/s]15:22:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:22
- cmdstanpy - INFO - Chain [1] start processing
# 15:22:23 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 81/2000 [00:34<12:36,  2.54it/s]15:22:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:23 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 82/2000 [00:34<12:47,  2.50it/s]15:22:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:23 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 83/2000 [00:35<12:09,  2.63it/s]15:22:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:24 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 84/2000 [00:35<12:37,  2.53it/s]15:22:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:24 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 85/2000 [00:36<12:34,  2.54it/s]15:22:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:25 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 86/2000 [00:36<12:29,  2.55it/s]15:22:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:25 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 87/2000 [00:36<12:52,  2.48it/s]15:22:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:25 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 88/2000 [00:37<12:49,  2.48it/s]15:22:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:26 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 89/2000 [00:37<12:37,  2.52it/s]15:22:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:26 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 90/2000 [00:38<13:20,  2.39it/s]15:22:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:27 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 91/2000 [00:38<14:03,  2.26it/s]15:22:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:27 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 92/2000 [00:39<14:22,  2.21it/s]15:22:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:28 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 93/2000 [00:39<14:12,  2.24it/s]15:22:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:28 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 94/2000 [00:39<14:15,  2.23it/s]15:22:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 95/2000 [00:40<13:57,  2.27it/s]15:22:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 96/2000 [00:40<14:06,  2.25it/s]15:22:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 97/2000 [00:41<14:41,  2.16it/s]15:22:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:30 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 98/2000 [00:41<13:45,  2.30it/s]15:22:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:30 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 99/2000 [00:42<13:10,  2.40it/s]15:22:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:31 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 100/2000 [00:42<14:09,  2.24it/s]15:22:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:31 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 101/2000 [00:43<14:14,  2.22it/s]15:22:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:32 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 102/2000 [00:43<13:56,  2.27it/s]15:22:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:32 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 103/2000 [00:43<13:37,  2.32it/s]15:22:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:32 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 104/2000 [00:44<13:10,  2.40it/s]15:22:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:22
- cmdstanpy - INFO - Chain [1] start processing
# 15:23:54 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 294/2000 [02:05<12:11,  2.33it/s]15:23:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:23:54 - cmdstanpy - INFO - Chain [1] done processing
# ...
#  95%|█████████▌| 1903/2000 [14:00<00:45,  2.14it/s]15:35:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:49 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1904/2000 [14:01<00:43,  2.23it/s]15:35:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:50 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1905/2000 [14:01<00:41,  2.26it/s]15:35:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:50 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1906/2000 [14:01<00:41,  2.28it/s]15:35:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:51 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1907/2000 [14:02<00:41,  2.22it/s]15:35:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:51 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1908/2000 [14:02<00:42,  2.18it/s]15:35:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:51 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1909/2000 [14:03<00:41,  2.19it/s]15:35:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:52 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1910/2000 [14:03<00:39,  2.29it/s]15:35:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:52 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1911/2000 [14:04<00:36,  2.44it/s]15:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:53 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1912/2000 [14:04<00:36,  2.40it/s]15:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:53 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1913/2000 [14:04<00:36,  2.38it/s]15:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:53 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1914/2000 [14:05<00:33,  2.54it/s]15:35:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:54 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1915/2000 [14:05<00:34,  2.46it/s]15:35:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:54 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1916/2000 [14:06<00:34,  2.45it/s]15:35:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:55 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1917/2000 [14:06<00:33,  2.44it/s]15:35:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:55 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1918/2000 [14:06<00:33,  2.42it/s]15:35:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:56 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1919/2000 [14:07<00:33,  2.42it/s]15:35:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:56 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1920/2000 [14:07<00:33,  2.41it/s]15:35:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:56 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1921/2000 [14:08<00:33,  2.33it/s]15:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:57 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1922/2000 [14:08<00:32,  2.43it/s]15:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:57 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1923/2000 [14:09<00:32,  2.38it/s]15:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:58 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1924/2000 [14:09<00:31,  2.41it/s]15:35:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:58 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1925/2000 [14:09<00:32,  2.28it/s]15:35:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:59 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1926/2000 [14:10<00:32,  2.26it/s]15:35:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:59 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1927/2000 [14:10<00:30,  2.40it/s]15:35:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:59 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1928/2000 [14:11<00:29,  2.45it/s]15:36:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:00 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1929/2000 [14:11<00:33,  2.09it/s]15:36:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:01 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1930/2000 [14:12<00:36,  1.90it/s]15:36:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:01 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1931/2000 [14:12<00:36,  1.89it/s]15:36:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:02 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1932/2000 [14:13<00:36,  1.85it/s]15:36:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:02 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1933/2000 [14:14<00:35,  1.88it/s]15:36:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:03 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1934/2000 [14:14<00:35,  1.86it/s]15:36:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:03 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1935/2000 [14:15<00:34,  1.90it/s]15:36:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:04 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1936/2000 [14:15<00:34,  1.87it/s]15:36:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:04 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1937/2000 [14:16<00:32,  1.91it/s]15:36:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:05 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1938/2000 [14:16<00:33,  1.83it/s]15:36:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:05 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1939/2000 [14:17<00:31,  1.93it/s]15:36:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:06 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1940/2000 [14:17<00:33,  1.77it/s]15:36:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:06 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1941/2000 [14:18<00:30,  1.93it/s]15:36:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:07 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1942/2000 [14:18<00:28,  2.02it/s]15:36:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:07 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1943/2000 [14:19<00:26,  2.16it/s]15:36:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:08 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1944/2000 [14:19<00:25,  2.20it/s]15:36:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:08 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1945/2000 [14:19<00:23,  2.33it/s]15:36:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:09 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1946/2000 [14:20<00:24,  2.19it/s]15:36:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:09 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1947/2000 [14:20<00:23,  2.29it/s]15:36:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:09 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1948/2000 [14:21<00:21,  2.43it/s]15:36:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:10 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1949/2000 [14:21<00:20,  2.45it/s]15:36:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:10 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1950/2000 [14:21<00:19,  2.52it/s]15:36:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:10 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1951/2000 [14:22<00:19,  2.49it/s]15:36:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:11 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1952/2000 [14:22<00:19,  2.45it/s]15:36:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:11 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1953/2000 [14:23<00:18,  2.55it/s]15:36:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:12 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1954/2000 [14:23<00:17,  2.58it/s]15:36:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:12 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1955/2000 [14:23<00:17,  2.59it/s]15:36:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:12 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1956/2000 [14:24<00:16,  2.59it/s]15:36:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:13 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1957/2000 [14:24<00:18,  2.30it/s]15:36:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:13 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1958/2000 [14:25<00:17,  2.41it/s]15:36:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:14 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1959/2000 [14:25<00:17,  2.40it/s]15:36:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:14 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1960/2000 [14:26<00:16,  2.43it/s]15:36:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:15 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1961/2000 [14:26<00:15,  2.51it/s]15:36:15 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:15 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1962/2000 [14:26<00:14,  2.57it/s]15:36:15 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:15 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1963/2000 [14:27<00:15,  2.44it/s]15:36:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:16 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1964/2000 [14:27<00:14,  2.46it/s]15:36:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:16 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1965/2000 [14:27<00:14,  2.49it/s]15:36:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:17 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1966/2000 [14:28<00:14,  2.29it/s]15:36:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:17 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1967/2000 [14:28<00:13,  2.38it/s]15:36:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:17 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1968/2000 [14:29<00:13,  2.29it/s]15:36:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:18 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1969/2000 [14:29<00:13,  2.38it/s]15:36:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:18 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1970/2000 [14:30<00:12,  2.37it/s]15:36:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:19 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1971/2000 [14:30<00:12,  2.41it/s]15:36:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:19 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1972/2000 [14:31<00:11,  2.37it/s]15:36:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:20 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1973/2000 [14:31<00:11,  2.28it/s]15:36:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:20 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1974/2000 [14:31<00:11,  2.27it/s]15:36:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:20 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1975/2000 [14:32<00:11,  2.27it/s]15:36:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:21 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1976/2000 [14:32<00:10,  2.35it/s]15:36:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:21 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1977/2000 [14:33<00:09,  2.34it/s]15:36:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:22 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1978/2000 [14:33<00:09,  2.32it/s]15:36:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:22 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1979/2000 [14:34<00:09,  2.28it/s]15:36:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:23 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1980/2000 [14:34<00:08,  2.33it/s]15:36:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:23 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1981/2000 [14:34<00:08,  2.32it/s]15:36:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:23 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1982/2000 [14:35<00:07,  2.39it/s]15:36:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:24 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1983/2000 [14:35<00:07,  2.33it/s]15:36:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:24 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1984/2000 [14:36<00:07,  2.26it/s]15:36:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:25 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1985/2000 [14:36<00:06,  2.27it/s]15:36:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:25 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1986/2000 [14:37<00:06,  2.21it/s]15:36:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:26 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1987/2000 [14:37<00:05,  2.22it/s]15:36:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:26 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1988/2000 [14:38<00:05,  2.25it/s]15:36:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:27 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1989/2000 [14:38<00:04,  2.26it/s]15:36:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:27 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1990/2000 [14:38<00:04,  2.23it/s]15:36:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:27 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1991/2000 [14:39<00:03,  2.33it/s]15:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:28 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1992/2000 [14:39<00:03,  2.23it/s]15:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:28 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1993/2000 [14:40<00:03,  2.24it/s]15:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1994/2000 [14:40<00:02,  2.31it/s]15:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1995/2000 [14:41<00:02,  2.29it/s]15:36:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:30 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1996/2000 [14:41<00:01,  2.32it/s]15:36:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:30 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1997/2000 [14:41<00:01,  2.34it/s]15:36:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:30 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1998/2000 [14:42<00:00,  2.42it/s]15:36:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:31 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1999/2000 [14:42<00:00,  2.37it/s]15:36:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:31 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2000/2000 [14:43<00:00,  2.26it/s]

# %% [markdown]
# ## Submit

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission
# Out:
#          종목코드    순위
# 0     A000020     1
# 1     A000040     2
# 2     A000050     3
# 3     A000070     4
# 4     A000080     5
# ...       ...   ...
# 1995  A375500  1996
# 1996  A378850  1997
# 1997  A383220  1998
# 1998  A383310  1999
# 1999  A383800  2000
#
# [2000 rows x 2 columns]

# %%
baseline_submission = sample_submission[['종목코드']].merge(results_df[['종목코드', '순위']], on='종목코드', how='left')
baseline_submission
# Out:
#          종목코드    순위
# 0     A000020   686
# 1     A000040  1597
# 2     A000050   669
# 3     A000070  1334
# 4     A000080   309
# ...       ...   ...
# 1995  A375500   409
# 1996  A378850  1296
# 1997  A383220   985
# 1998  A383310  1446
# 1999  A383800   627
#
# [2000 rows x 2 columns]

# %%
baseline_submission.to_csv('baseline_prophet.csv', index=False)

# %%
answer_df = pd.read_csv('Answer_real.csv', encoding = "CP949")
answer_df = answer_df[['종목코드','등락률']]
answer_df = answer_df.sort_values('종목코드')
answer_df

# %%
prediction_df = pred_df[['종목코드','rate']]
prediction_df.rename(columns={'rate': '등락률'}, inplace=True)
prediction_df

# %%
answer_df = answer_df[answer_df['종목코드'].isin(prediction_df['종목코드'])]
answer_df = answer_df.reset_index(drop = True)
answer_df

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error

# 정답 데이터프레임과 예측 결과 데이터프레임은 pandas DataFrame 형태라고 가정합니다.
# 등락률은 실수 형태의 값이라고 가정하고, 부호에 따라 'up' 또는 'down'으로 분류합니다.

# 등락률의 부호에 따른 분류 결과를 새로운 열로 추가합니다.
answer_df['trend'] = answer_df['등락률'].apply(lambda x: 'up' if x > 0 else 'down')
prediction_df['trend'] = prediction_df['등락률'].apply(lambda x: 'up' if x > 0 else 'down')

# 1. 전체 종목에 대한 Accuracy
total_accuracy = accuracy_score(answer_df['trend'], prediction_df['trend'])

# 변동률이 높은 상위 200개 및 하위 200개 종목 추출
top200_df = answer_df.sort_values(by='등락률', ascending=False).head(200)
bottom200_df = answer_df.sort_values(by='등락률', ascending=True).head(200)

# 2. 상위 200개 종목 및 하위 200개 종목에 대한 Accuracy
top200_accuracy = accuracy_score(top200_df['trend'], prediction_df.loc[top200_df.index, 'trend'])
bottom200_accuracy = accuracy_score(bottom200_df['trend'], prediction_df.loc[bottom200_df.index, 'trend'])

# 3. 상위 200개 종목 및 하위 200개 종목에 대한 MAE
# 이 경우 '등락률'은 실제 변동률을 예측한 연속적인 값이라고 가정합니다.
top200_mae = mean_absolute_error(top200_df['등락률'], prediction_df.loc[top200_df.index, '등락률'])
bottom200_mae = mean_absolute_error(bottom200_df['등락률'], prediction_df.loc[bottom200_df.index, '등락률'])

print("Total Accuracy: ", total_accuracy)
print("Top 200 Accuracy: ", top200_accuracy)
print("Bottom 200 Accuracy: ", bottom200_accuracy)
print("Top 200 MAE: ", top200_mae)
print("Bottom 200 MAE: ", bottom200_mae)
